# %%
#라이브러리 불러오기
from sklearn.datasets import load_iris

# %%
#붓꽃 파일 속성 변수 지정
iris = load_iris()

X = iris.data[:, :2] 
y = iris.target

# %%
# 모델 생성 및 데이터 훈련 / 결정트리 깊이는 2로 지정
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 2)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
# 트리 구조 그래프 그리기
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\admin\anaconda33\lib\site-packages (0.18.2)
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.tree import export_graphviz
import graphviz
export_graphviz(
    clf,
    out_file = "./iris.dot",
    feature_names = iris.feature_names[:2],
    class_names = iris.target_names,
    filled = True
    )

with open("./iris.dot") as f:
    dot_graph = str(open("./iris.dot", "rb").read(), "utf8")
graphviz.Source(dot_graph)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.xlim(4, 8.5)
plt.ylim(1.5, 4.5)

markers = ['o', '+', '^']
for i in range(3):
    xs = X[:, 0][y == i]
    ys = X[:, 1][y == i]
    plt.scatter(xs, ys, marker=markers[i])

plt.legend(iris.target_names)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")


# 결정 트리 경계선: 실선은 루트 노드 점선은 자식 노드
xx = np.linspace(5.45, 5.45, 3)
yy = np.linspace(1.5, 4.5, 3)
plt.plot(xx, yy, '-k') # 검정색 실선

xx = np.linspace(4, 5.45, 3)
yy = np.linspace(2.8, 2.8, 3)
plt.plot(xx, yy, '--b') # 파란색 점선

xx = np.linspace(6.15, 6.15, 3)
yy = np.linspace(1.5, 4.5, 3)
plt.plot(xx, yy, '--r') # 붉은색 점선

print(clf.predict([[5.5, 4]]))

print(clf.predict_proba([[5.5, 4]]))
# Out:
# [1]
# [[0.11627907 0.65116279 0.23255814]]

# %%
print(clf.predict([[5.5, 4]]))
# Out:
# [1]

# %%
print(clf.predict_proba([[5.5, 4]]))
# Out:
# [[0.11627907 0.65116279 0.23255814]]
